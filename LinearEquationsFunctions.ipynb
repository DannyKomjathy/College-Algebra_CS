# %%
# Solving a system of linear equations using matrices
import numpy as np

# Coefficient matrix
A = np.array([[2, 3], [4, -1]])

# Constant vector
b = np.array([8, 1])

# Solve the system
x = np.linalg.solve(A, b)

# Print the solution
print("Solution:", x)
# Out:
# Solution: [0.78571429 2.14285714]
